# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.51.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow<22,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.10.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
import pandas as pd
dt = pd.read_csv("/content/creditcard.csv", delimiter=',', on_bad_lines='skip')
dt
# Out:
# /tmp/ipython-input-3419410484.py:2: DtypeWarning: Columns (1,2,4,5,6,8,9,10,11,12,14,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   dt = pd.read_csv("/content/creditcard.csv", delimiter=',', on_bad_lines='skip')
#             Time         V1         V2        V3                  V4  \
# 0            0.0  -1.359807  -0.072781  2.536347            1.378155
# 1            0.0   1.191857   0.266151  0.166480            0.448154
# 2            1.0  -1.358354  -1.340163  1.773209             0.37978
# 3            1.0  -0.966272  -0.185226  1.792993           -0.863291
# 4            2.0  -1.158233   0.877737  1.548718            0.403034
# ...          ...        ...        ...       ...                 ...
# 547605  172786.0 -11.881118  10.071785 -9.834783   -2.06665568459413
# 547606  172787.0  -0.732789   -0.05508  2.035030   -0.73858858438744
# 547607  172788.0   1.919565  -0.301254 -3.249640   -0.55782812475002
# 547608  172788.0   -0.24044   0.530483  0.702510   0.689799168040973
# 547609  172792.0  -0.533413  -0.189733  0.703337  -0.506271240328258
#
#                          V5                   V6        V7        V8  \
# 0        -0.338320769942518    0.462387777762292  0.239599  0.098698
# 1        0.0600176492822243  -0.0823608088155687 -0.078803  0.085102
# 2        -0.503198133318193     1.80049938079263  0.791461  0.247676
# 3       -0.0103088796030823     1.24720316752486  0.237609  0.377436
# 4        -0.407193377311653   0.0959214624684256  0.592941 -0.270533
# ...                     ...                  ...       ...       ...
# 547605            -5.364473            -2.606837 -4.918215  7.305334
# 547606             0.868229             1.058415  0.024330  0.294869
# 547607             2.630515              3.03126 -0.296827  0.708417
# 547608            -0.377961             0.623708 -0.686180  0.679145
# 547609            -0.012546            -0.649617  1.577006  -0.41465
#
#               V9  ...       V21       V22       V23       V24       V25  \
# 0       0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1      -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2      -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3      -1.387024  ...   -0.1083  0.005274 -0.190321 -1.175575  0.647376
# 4       0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# ...          ...  ...       ...       ...       ...       ...       ...
# 547605  1.914428  ...  0.213454  0.111864  1.014480 -0.509348  1.436807
# 547606    0.5848  ...  0.214205  0.924384  0.012463 -1.016226 -0.606624
# 547607  0.432454  ...  0.232045  0.578229 -0.037501  0.640134  0.265745
# 547608  0.392087  ...  0.265245  0.800049 -0.163298  0.123205 -0.569159
# 547609   0.48618  ...  0.261057  0.643078  0.376777  0.008797 -0.473649
#
#              V26       V27       V28  Amount  Class
# 0      -0.189115  0.133558 -0.021053  149.62    0.0
# 1       0.125895 -0.008983  0.014724    2.69    0.0
# 2      -0.139097 -0.055353 -0.059752  378.66    0.0
# 3      -0.221929  0.062723  0.061458  123.50    0.0
# 4       0.502292  0.219422  0.215153   69.99    0.0
# ...          ...       ...       ...     ...    ...
# 547605  0.250034  0.943651  0.823731    0.77    0.0
# 547606 -0.395255  0.068472 -0.053527   24.79    0.0
# 547607 -0.087371  0.004455 -0.026561   67.88    0.0
# 547608  0.546668  0.108821  0.104533   10.00    0.0
# 547609 -0.818267 -0.002415  0.013649  217.00    0.0
#
# [547610 rows x 31 columns]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547610 entries, 0 to 547609
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    547610 non-null  float64
#  1   V1      547610 non-null  object
#  2   V2      547610 non-null  object
#  3   V3      547610 non-null  float64
#  4   V4      547610 non-null  object
#  5   V5      547608 non-null  object
#  6   V6      547608 non-null  object
#  7   V7      547606 non-null  float64
#  8   V8      547602 non-null  object
#  9   V9      547601 non-null  object
#  10  V10     547598 non-null  object
#  11  V11     547594 non-null  object
#  12  V12     547591 non-null  object
#  13  V13     547589 non-null  float64
#  14  V14     547583 non-null  object
#  15  V15     547576 non-null  float64
#  16  V16     547570 non-null  float64
#  17  V17     547567 non-null  float64
#  18  V18     547566 non-null  float64
#  19  V19     547561 non-null  float64
#  20  V20     547554 non-null  object
#  21  V21     547547 non-null  object
#  22  V22     547539 non-null  float64
#  23  V23     547533 non-null  float64
#  24  V24     547527 non-null  float64
#  25  V25     547517 non-null  float64
#  26  V26     547509 non-null  float64
#  27  V27     547503 non-null  float64
#  28  V28     547495 non-null  float64
#  29  Amount  547485 non-null  float64
#  30  Class   547476 non-null  float64
# dtypes: float64(18), object(13)
# memory usage: 129.5+ MB

# %%
dt = dt.apply(pd.to_numeric, errors='coerce')
display(dt.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547610 entries, 0 to 547609
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    547610 non-null  float64
#  1   V1      547609 non-null  float64
#  2   V2      547609 non-null  float64
#  3   V3      547610 non-null  float64
#  4   V4      547608 non-null  float64
#  5   V5      547607 non-null  float64
#  6   V6      547605 non-null  float64
#  7   V7      547606 non-null  float64
#  8   V8      547600 non-null  float64
#  9   V9      547600 non-null  float64
#  10  V10     547597 non-null  float64
#  11  V11     547592 non-null  float64
#  12  V12     547589 non-null  float64
#  13  V13     547589 non-null  float64
#  14  V14     547580 non-null  float64
#  15  V15     547576 non-null  float64
#  16  V16     547570 non-null  float64
#  17  V17     547567 non-null  float64
#  18  V18     547566 non-null  float64
#  19  V19     547561 non-null  float64
#  20  V20     547553 non-null  float64
#  21  V21     547545 non-null  float64
#  22  V22     547539 non-null  float64
#  23  V23     547533 non-null  float64
#  24  V24     547527 non-null  float64
#  25  V25     547517 non-null  float64
#  26  V26     547509 non-null  float64
#  27  V27     547503 non-null  float64
#  28  V28     547495 non-null  float64
#  29  Amount  547485 non-null  float64
#  30  Class   547476 non-null  float64
# dtypes: float64(31)
# memory usage: 129.5 MB
# None

# %%
duplicates = dt.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 263877

# %%
print(f"Number of rows: {dt.shape[0]}")
print(f"Number of columns: {dt.shape[1]}")
# Out:
# Number of rows: 547610
# Number of columns: 31

# %%
dt.isnull().sum()
# Out:
# Time        0
# V1          1
# V2          1
# V3          0
# V4          2
# V5          3
# V6          5
# V7          4
# V8         10
# V9         10
# V10        13
# V11        18
# V12        21
# V13        21
# V14        30
# V15        34
# V16        40
# V17        43
# V18        44
# V19        49
# V20        57
# V21        65
# V22        71
# V23        77
# V24        83
# V25        93
# V26       101
# V27       107
# V28       115
# Amount    125
# Class     134
# dtype: int64

# %%
dt.dropna(inplace=True)
print("Null values after dropping rows:")
print(dt.isnull().sum())
# Out:
# Null values after dropping rows:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
numerical_cols = dt.select_dtypes(include=['float64', 'int64']).columns
scaler = MinMaxScaler()
dt[numerical_cols] = scaler.fit_transform(dt[numerical_cols])

display(dt.head())
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  0.000000  0.935192  0.766490  0.881365  0.313023  0.763439  0.267669
# 1  0.000000  0.978542  0.770067  0.840298  0.271796  0.766120  0.262192
# 2  0.000006  0.935217  0.753118  0.868141  0.268766  0.762329  0.281122
# 3  0.000006  0.941878  0.765304  0.868484  0.213661  0.765647  0.275559
# 4  0.000012  0.938617  0.776520  0.864251  0.269796  0.762975  0.263984
#
#          V7        V8        V9  ...       V21  V22       V23       V24  \
# 0  0.266815  0.786444  0.476562  ...  0.561184  1.0  0.663793  0.391253
# 1  0.264875  0.786298  0.455078  ...  0.557840  1.0  0.666938  0.336440
# 2  0.270177  0.788042  0.410156  ...  0.565477  1.0  0.678939  0.289354
# 3  0.266803  0.789434  0.414062  ...  0.559734  1.0  0.662607  0.223826
# 4  0.268968  0.782484  0.492188  ...  0.561327  1.0  0.663392  0.401270
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.585122  0.394557  0.418976  0.312697  0.005824    0.0
# 1  0.587290  0.446013  0.416345  0.313423  0.000105    0.0
# 2  0.559515  0.402727  0.415489  0.311911  0.014739    0.0
# 3  0.614245  0.389197  0.417669  0.314371  0.004807    0.0
# 4  0.566343  0.507497  0.420561  0.317490  0.002724    0.0
#
# [5 rows x 31 columns]

# %%
x = dt.drop('Class', axis=1)
y = dt['Class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score = model.score(x_test, y_test)
print(f"Accuracy Score: {accuracy_score}")
# Out:
# Accuracy Score: 0.9991597789853418

# %%
import pickle

filename = 'credit_fraud.pkl'
pickle.dump(model, open(filename, 'wb'))

print(f"Model successfully pickled to {filename}")
# Out:
# Model successfully pickled to credit_fraud.pkl

# %%
import streamlit as st
import pandas as pd
import joblib

# Load model
model = joblib.load("credit_fraud.pkl")

st.title("💳 Credit Card Fraud Detection App")
st.write("Enter transaction details below to predict if it's fraudulent.")

# Input fields for features
v1 = st.number_input("V1")
v2 = st.number_input("V2")
v3 = st.number_input("V3")
amount = st.number_input("Transaction Amount")

# When the user clicks the predict button
if st.button("Predict"):
    # Create a DataFrame with the inputs
    data = pd.DataFrame([[v1, v2, v3, amount]], columns=["V1", "V2", "V3", "Amount"])

    # Make prediction
    prediction = model.predict(data)[0]

    if prediction == 1:
        st.error("⚠️ This transaction is **FRAUDULENT!**")
    else:
        st.success("✅ This transaction seems **legitimate.**")
# Out:
# 2025-11-11 10:17:16.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 10:17:16.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# The Streamlit app is now running. Click on the public URL provided in the output of the previous cell to access it. It might take a few moments for the app to become available.
#
# **Note:** This Streamlit app uses only a subset of the features (V1, V2, V3, Amount) for prediction and does not apply the necessary scaling that was used during model training. This will likely lead to inaccurate predictions. A more robust application would require collecting inputs for all features the model was trained on and applying the same preprocessing steps (like scaling) to the input data before making a prediction.

# %%
import joblib

# Save trained model
joblib.dump(model, "credit_fraud.pkl")
# Out:
# ['credit_fraud.pkl']
